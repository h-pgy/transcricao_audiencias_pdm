# %%
from core.blob_storage import WavToBlobUploader, generate_sas_token
from core.azure_speech_to_text.batch_transcription import AzureBatchTranscriptionClient
from config import (
        AZURE_STORAGE_AUDIO_CONTAINER_NAME, 
        AZURE_STORAGE_CONNECTION_STRING, 
        AZURE_STORAGE_TRANSCRIPTIONS_CONTAINER_NAME, 
        AZURE_SPEECH_KEY,
        AZURE_SPEECH_REGION
)

# %%
blob = WavToBlobUploader()

# %%
audio_file_token = blob('test_audio1.wav', 'teste_hoje.wav')
# Out:
# Uploaded c:\Users\d835916\projetos\transcricao_audiencias_pdm\temp_data\youtube_wav_files\test_audio1.wav to audios/teste_hoje.wav

# %%
container_token =generate_sas_token(AZURE_STORAGE_TRANSCRIPTIONS_CONTAINER_NAME, container_token=True)

# %%
container_token
# Out:
# 'https://transcricoespdm.blob.core.windows.net/transcricoes?se=2025-05-15T16%3A01%3A15Z&sp=racwle&sv=2025-05-05&sr=c&sig=plgI3MbmD8OVLE%2BQYbu%2B168O9Ui%2BYpMculuRqU65r9g%3D'

# %%
speech_text_client = AzureBatchTranscriptionClient()

# %%
speech_text_client([audio_file_token], container_token)
# Out:
# Posting to Azure API: https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions
# Transcription job started. Status URL: https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions/91bcd60f-5dd0-4150-bc43-fc9b122102ae
# Transcription job status: Running
# Waiting for 10 seconds before checking the status again...
# Transcription job status: Running
# Waiting for 10 seconds before checking the status again...
# Transcription job status: Running
# Waiting for 10 seconds before checking the status again...
# Transcription job status: Succeeded
# Transcription job succeeded.Response: {'self': 'https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions/91bcd60f-5dd0-4150-bc43-fc9b122102ae', 'displayName': 'batch_transcription', 'locale': 'pt-BR', 'createdDateTime': '2025-05-15T15:01:15Z', 'lastActionDateTime': '2025-05-15T15:01:43Z', 'status': 'Succeeded', 'model': {'self': 'https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/models/base/4f99466a-053e-4cbb-8a9e-a6acfd28bf60'}, 'links': {'files': 'https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions/91bcd60f-5dd0-4150-bc43-fc9b122102ae/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'displayFormWordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'DictatedAndAutomatic', 'profanityFilterMode': 'None', 'destinationContainerUrl': 'https://transcricoespdm.blob.core.windows.net/transcricoes?se=2025-05-15T16%3A01%3A15Z&sp=racwle&sv=2025-05-05&sr=c&sig=plgI3MbmD8OVLE%2BQYbu%2B168O9Ui%2BYpMculuRqU65r9g%3D', 'duration': 'PT59S'}}
# {'values': [{'self': 'https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions/91bcd60f-5dd0-4150-bc43-fc9b122102ae/files/b599b146-ff87-43aa-96e5-4c46d8865bf3',
#    'name': 'contenturl_0.json',
#    'kind': 'Transcription',
#    'links': {'contentUrl': 'https://transcricoespdm.blob.core.windows.net/transcricoes/91bcd60f-5dd0-4150-bc43-fc9b122102ae/contenturl_0.json'},
#    'properties': {'size': 38160},
#    'createdDateTime': '2025-05-15T15:01:43Z'},
#   {'self': 'https://brazilsouth.api.cognitive.microsoft.com/speechtotext/v3.2/transcriptions/91bcd60f-5dd0-4150-bc43-fc9b122102ae/files/d3360cbe-f95f-478a-8f67-f214d6550dc1',
#    'name': 'report.json',
#    'kind': 'TranscriptionReport',
#    'links': {'contentUrl': 'https://transcricoespdm.blob.core.windows.net/transcricoes/91bcd60f-5dd0-4150-bc43-fc9b122102ae/91bcd60f-5dd0-4150-bc43-fc9b122102ae_report.json'},
#    'properties': {'size': 344},
#    'createdDateTime': '2025-05-15T15:01:43Z'}]}
